# %%
import pandas as pd
import requests
movie_data_csv = "movies_metadata.csv"

# %%
movie_data = pd.read_csv(movie_data_csv)
movie_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movie_data_filtered_date = movie_data[(movie_data["release_date"] > "2007-01-01") & (movie_data["release_date"] < "2009-12-31")]

# %%
len(movie_data_filtered_date)
# Out:
# 4257

# %%
movie_data_filtered_final = movie_data_filtered_date[movie_data_filtered_date['original_language']=="en"]

# %%
len(movie_data_filtered_final)
# Out:
# 2993

# %%
movie_data_filtered_final.head()
# Out:
#        adult                              belongs_to_collection    budget  \
# 11472  False                                                NaN  21000000
# 11497  False                                                NaN  20000000
# 11498  False  {'id': 160727, 'name': 'Stomp the Yard Collect...  13000000
# 11519  False                                                NaN         0
# 11521  False                                                NaN  10000000
#
#                                                   genres  \
# 11472  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 11497  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 11498  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 11519                  [{'id': 12, 'name': 'Adventure'}]
# 11521  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
#
#                              homepage     id    imdb_id original_language  \
# 11472  http://www.freedomwriters.com/   1646  tt0463998                en
# ...

# %%
movie_data_titles = movie_data_filtered_final['original_title']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-729f84db3118> in <module>
# ----> 1 movie_data_titles = movie_data_filtered_final['original_title']
#
# NameError: name 'movie_data_filtered_final' is not defined

# %%
imdbRating = []
base_url =

# %%
key = '8a3856d'
url = f'http://www.omdbapi.com/?apikey={key}&t={imdbRating}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-24a473d38cbb> in <module>
#       1 key = '8a3856d'
# ----> 2 url = f'http://www.omdbapi.com/?apikey={key}&t={imdbRating}'
#
# NameError: name 'imdbRating' is not defined

# %%
{imdbRating} = requests.get(url).json()
# Out:
#   File "<ipython-input-6-f895010e320c>", line 1
#     {imdbRating} = requests.get(url).json()
#                                            ^
# SyntaxError: can't assign to literal

# %%
print{imdbRating}
# Out:
# {'Title': 'Waitress', 'Year': '2007', 'Rated': 'PG-13', 'Released': '25 May 2007', 'Runtime': '108 min', 'Genre': 'Comedy, Drama, Romance', 'Director': 'Adrienne Shelly', 'Writer': 'Adrienne Shelly', 'Actors': 'Keri Russell, Nathan Fillion, Cheryl Hines, Jeremy Sisto', 'Plot': 'Jenna is a pregnant, unhappily married waitress in the deep south. She meets a newcomer to her town and falls into an unlikely relationship as a last attempt at happiness.', 'Language': 'English', 'Country': 'USA', 'Awards': '6 wins & 15 nominations.', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc4ODI2MjU2M15BMl5BanBnXkFtZTcwOTAzNzU0MQ@@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'}, {'Source': 'Rotten Tomatoes', 'Value': '90%'}, {'Source': 'Metacritic', 'Value': '75/100'}], 'Metascore': '75', 'imdbRating': '7.0', 'imdbVotes': '41,767', 'imdbID': 'tt0473308', 'Type': 'movie', 'DVD': '27 Nov 2007', 'BoxOffice': '$18,699,775', 'Production': 'Fox Searchlight Picture
# ...

# %%
# Start constructing a for loop so that you go through all movie titles and collect the imbdID rating
# from the json response above

import json

# To do so, use this fstring template to call the api (requests.get) once per movie title and save that response into
# a variable, then from that variable extract the imbdRating. From there store this value in the same row of the 
# movie_data_titles dataframe respectivly (maybe make a new dataframe with structure: movie_title, imbd_rating and
# then insert the key value pair into the corresponding dataframe...so like, movie_title: "waitress", imbd_rating: "7.0"
# ...take that data and insert it into a row of a dataframe)

# Template string that you can use for GET calls:
url = f'http://www.omdbapi.com/?apikey={key}&t={imdbRating}'

# To fill in "movie_title" each time in the for loop, you can do something like: for movie_title in movie_data_titles:
# and then movie_title is selected from the dataframe and use that string to fill in the fstring url

# Lastly, save your newly constructed dataframe (the movie_title, imbd_rating one) to a csv like you did before for 
# movie titles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1216f4c5b851> in <module>
#      11
#      12 # Template string that you can use for GET calls:
# ---> 13 url = f'http://www.omdbapi.com/?apikey={key}&t={movie_title}'
#      14
#      15 # To fill in "movie_title" each time in the for loop, you can do something like: for movie_title in movie_data_titles:
#
# NameError: name 'key' is not defined

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
